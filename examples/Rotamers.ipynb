# %%
import offpele.topology.molecule as mol

# %%
molecule = mol.Molecule('../data/ligands/SBN.pdb')
molecule.parameterize('openff-1.1.1.offxml')
molecule.plot_rotamer_graph()
# Out:
#  - Loading molecule from RDKit
# ...
#  - Loading forcefield
#  - Computing partial charges with am1bcc

# %%
molecule.build_rotamer_library(resolution=30)
# Out:
#  - Generating rotamer library

# %%
molecule.rotamer_library.to_file('../data/templates/SBN.rot.assign')
